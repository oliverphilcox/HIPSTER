# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hipster_power = np.loadtxt('output/mock_1_DD_power_counts_n20_l4_full.txt')
k_bins = np.loadtxt('/Users/ophilcox/hipster_data/k_bins.txt').mean(axis=1)

# %%
for i in range(3):
    plt.plot(k_bins,hipster_power[:,i]*k_bins)

# %%
### Generate some randoms
L_box = 1000
rand_xyz=np.random.uniform(0.,L_box,size=(100000,3))
rand_w = np.ones((100000,1))
rand_all = np.hstack([rand_xyz,rand_w])
np.savetxt('/Users/ophilcox/hipster_data/rand_1e5',rand_all)
