# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hipster_power1 = np.loadtxt('output/test_power_spectrum_n29_l2.txt')
hipster_power2 = np.loadtxt('output/test2_power_spectrum_n29_l2.txt')
hipster_power3 = np.loadtxt('output/test3_power_spectrum_n29_l2.txt')
k_bins = np.loadtxt('/Users/ophilcox/hipster_data/k_bins.txt').mean(axis=1)

# %%
cols = ['r','b','g']
for i in range(1):
    plt.plot(k_bins,hipster_power1[:,i]*k_bins,c=cols[i],ls='-')
    plt.plot(k_bins,hipster_power2[:,i]*k_bins,c=cols[i],ls='--')
    plt.plot(k_bins,hipster_power3[:,i]*k_bins,c=cols[i],ls='--')

# %%
plt.plot(k_bins,(hipster_power25[:,i]-hipster_power100[:,i])/hipster_power100[:,i])

# %% [markdown]
# ## Load in Nbodykit data

# %%
nbody_power = np.load('../hipster_data/hipster_mock_1_test.npz',allow_pickle=True)

# %%
cols = ['r','b','g']
for i in range(3):
    #plt.plot(k_bins,hipster_power50[:,i]*k_bins,c=cols[i],ls='--')
    plt.plot(k_bins,hipster_power100[:,i]*k_bins,c=cols[i],ls='-')
    plt.plot(nbody_power['k'][2],nbody_power['k'][2]*nbody_power['p%s'%(2*i)][2],ls='',marker='x',c=cols[i])

# %%
for i in range(1):
    plt.plot(k_bins,hipster_power1[:,i])
    plt.plot(k_bins,hipster_power2[:,i])
    plt.plot(k_bins,np.abs(hipster_power3[:,i]))
plt.yscale('log')

# %%
hipster_power_DD/10-hipster_power_RR
# Out:
# array([[ 2.99050220e+05,  6.19342500e+00, -1.10800700e+00],
#        [ 3.53143063e+05,  2.67230700e+01, -1.96447400e+01],
#        [ 3.35095761e+05,  6.38774000e+01, -1.12638400e+02],
#        [ 3.08075240e+05,  1.12976000e+02, -3.75418800e+02],
#        [ 2.76474384e+05,  1.67230200e+02, -9.13204800e+02],
#        [ 2.40353116e+05,  2.19114800e+02, -1.80601800e+03],
#        [ 2.02680920e+05,  2.61411500e+02, -3.07632800e+03],
#        [ 1.65273793e+05,  2.88154500e+02, -4.66745400e+03],
#        [ 1.29940315e+05,  2.95362300e+02, -6.43845800e+03],
#        [ 9.81297617e+04,  2.81463900e+02, -8.17770600e+03],
#        [ 7.08017999e+04,  2.47379800e+02, -9.63316500e+03],
#        [ 4.84394463e+04,  1.96270600e+02, -1.05539100e+04],
#        [ 3.11054080e+04,  1.33015700e+02, -1.07347500e+04],
#        [ 1.84696096e+04,  6.35168300e+01, -1.00552700e+04],
#        [ 9.93396665e+03, -6.06431100e+00, -8.50546600e+03],
#        [ 4.73625959e+03, -7.00253700e+01, -6.19300800e+03],
#        [ 2.05188593e+03, -1.23713400e+02, -3.33059800e+03],
#        [ 1.08897293e+03, -1.63926300e+02, -2.05839100e+02],
#        [ 1.15669527e+03, -1.89099400e+02,  2.86085300e+03],
#        [ 1.70451847e+03, -1.99284400e+02,  5.56270400e+03]])

# %%
### Generate some randoms
L_box = 1000
rand_xyz=np.random.uniform(0.,L_box,size=(100000,3))
rand_w = np.ones((100000,1))
rand_all = np.hstack([rand_xyz,rand_w])
np.savetxt('/Users/ophilcox/hipster_data/rand_test',rand_all)
